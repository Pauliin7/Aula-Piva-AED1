# %%
flag = 1
while flag <= 5:
    print ("Olá, estamos na aula 7, no dia 24/03")
    flag = flag + 1
# Out:
# Olá, estamos na aula 7, no dia 24/03
# Olá, estamos na aula 7, no dia 24/03
# Olá, estamos na aula 7, no dia 24/03
# Olá, estamos na aula 7, no dia 24/03
# Olá, estamos na aula 7, no dia 24/03

# %%
for x in range(1,100,10):
    print(x)
# Out:
# 1
# 11
# 21
# 31
# 41
# 51
# 61
# 71
# 81
# 91

# %%
nome = input ("Digite o seu nome:")
for letra in nome:
    print(letra)
# Out:
# Digite o seu nome: paulo alexandre
# p
# a
# u
# l
# o
#
# a
# l
# e
# x
# a
# n
# d
# r
# e
