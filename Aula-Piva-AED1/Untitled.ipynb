# %%
import random 
n_secreto = random.randint(1,50)
while tentativa < 5:
    palpite = int(input("Digite um palpite"))
    if palpite == n_secreto:
        print("Voce acertou!!")
        break
    else:
        print("Errou")
        if palpite > n_secreto:
           print("Tente um num menor")
        else:
           print("Tente um num maior")
           tentativa = tentativa + 1

# %%
import random
n_secreto = random.randint(1,50)
for i in range (5):
    palpite = int(input("Digite seu palpite"))
    if palpite == n_secreto:
        print("Acertou!!!!")
    else
